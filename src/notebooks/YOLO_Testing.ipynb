# %%
# !pip install yolov5 --quiet

# %%
import yolov5

# %%
# %cd /Users/sumukhiganesan/GitHub/ds5500-capstone-project/yolov5
# Out:
# /Users/sumukhiganesan/GitHub/ds5500-capstone-project/yolov5

# %%
# Load custom models
model1 = yolov5.load('runs/train/exp1/weights/best.pt')  
model2 = yolov5.load('runs/train/exp2/weights/best.pt') 
model3 = yolov5.load('runs/train/exp3/weights/best.pt')

# %%
img = '../datasets/custom_dataset/images/test/00020.png'

# %%
results = model3(img)

# %%
results
# Out:
# YOLOv5 <class 'yolov5.models.common.Detections'> instance
# image 1/1: 150x1271 23 items
# Speed: 20.0ms pre-process, 78.9ms inference, 1.1ms NMS per image at shape (1, 3, 96, 640)

# %%
predictions = results.pred[0]
boxes = predictions[:, :4] # x1, y1, x2, y2
scores = predictions[:, 4]
categories = predictions[:, 5]

# %%
results.show()
# Out:
# <PIL.Image.Image image mode=RGB size=1271x150>

# %%
# !python val.py --weights runs/train/exp3/weights/best.pt --data ../datasets/custom_dataset.yaml --task test --single-cls
# Out:
# val: data=../datasets/custom_dataset.yaml, weights=['runs/train/exp3/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=True, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-287-g574331f9 Python-3.9.7 torch-2.0.0 CPU
#
# Fusing layers...
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# YOLOv5s summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# test: Scanning /Users/sumukhiganesan/GitHub/ds5500-capstone-project/datasets/cus
# test: New cache created: /Users/sumukhiganesan/GitHub/ds5500-capstone-project/datasets/custom_dataset/labels/test.cache
#                  Class     Images  Instances          P          R      mAP50
#                    all       1500      13261      0.965      0.944      0.976      0.773
# Speed: 0.9ms pre-process, 213.9ms inference, 1.5ms NMS per image at shape (32, 3, 640, 640)
# Results saved to runs/val/exp2
